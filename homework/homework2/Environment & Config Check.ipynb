# %%
from src import config
import numpy as np
# Out:
# Loaded .env (if present)
# API_KEY is present: True

# %%
arr = np.array([58, 49, 91, 92, 35, 56, 40,  9])
arr += arr ** 2
arr
# Out:
# array([3422, 2450, 8372, 8556, 1260, 3192, 1640,   90])

# %%
# Export Requirements
# !pip freeze > requirements.txt
